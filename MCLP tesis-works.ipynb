# %%
import pulp
import pandas as pd
import numpy as np

# %%
# Load the distance matrix from an Excel file
excel_file = "distance_matrix.xlsx"  
dfs = pd.read_excel(excel_file, index_col=0, engine='openpyxl')

df = dfs.copy()

demand_i = np.random.rand(df.shape[1])*1000 #demand aslinya 
demands = {city : demand for city, demand in zip(df.columns,demand_i)}

# %%
# Define your parameters
facilities = df.columns.tolist()  # Facility locations
demand_points = df.index.tolist()  # Demand points
k = 3  # Number of facilities to open
maximum_coverage = 10000

# %%
# Create a PuLP linear programming problem
problem = pulp.LpProblem("MCLP", pulp.LpMaximize)

# %%
# Define binary variables for facility opening decision
facility_open = {j: pulp.LpVariable("x " + j, cat=pulp.LpBinary) for j in facilities}   #x
demand_point = {i: pulp.LpVariable("y " + i, cat=pulp.LpBinary) for i in demand_points}  #y
#demand_number = {i: pulp.LpVariable(i, cat=pulp.LpBinary) for i in demand_i} #a
# demand_fulfilled = pulp.LpVariable.dicts("demand_fulfilled", demand_points, cat='Binary')
# demand_fulfilled
#demand_point

# %%
# Define the objective function (maximize coverage)
problem += pulp.lpSum([demands[d] * demand_point[d] for d in demand_point])
problem
# Out:
# MCLP:
# MAXIMIZE
# 589.8425549887097*y_Bandongan + 980.968821859348*y_Bayat + 586.2986719984674*y_Borobudur + 629.1994433433433*y_Candimulyo + 920.9271724989774*y_Cawas + 293.99446779335494*y_Ceper + 900.2234981668339*y_Delanggu + 322.61594735041666*y_Dukun + 121.40895106316829*y_Gantiwarno + 810.912528588859*y_Grabag + 963.0687045665818*y_Jatinom + 301.2064840143849*y_Jogonalan + 511.54252866204854*y_Juwiring + 559.9575368977414*y_KAPANEWON_BAMBANG_LIPURO + 363.4851455257291*y_KAPANEWON_BANGUNTAPAN + 963.5657054103127*y_KAPANEWON_BANTUL + 325.748664394955*y_KAPANEWON_BERBAH + 471.4036913074094*y_KAPANEWON_CANGKRINGAN + 316.3457972476483*y_KAPANEWON_DEPOK + 509.5108059553727*y_KAPANEWON_DLINGO + 693.0510815699544*y_KAPANEWON_GALUR + 643.9988809030568*y_KAPANEWON_GAMPING + 558.0080408057444*y_KAPANEWON_GEDANGSARI + 836.9982538015092*y_KAPANEWON_GIRIMULYO + 657.571223346218*y_KAPANEWON_GIRISUBO + 238.89131128752993*y_KAPANEWON_GODEAN + 332.3022880699811*y_KAPANEWON_IMOGIRI + 588.9180160669276*y_KAPANEWON_JETIS + 328.0971232962794*y_KAPANEWON_KALASAN + 87.69843009707668*y_KAPANEWON_KALIBAWANG + 491.5255943534368*y_KAPANEWON_KARANGMOJO + 943.0368326733397*y_KAPANEWON_KASIHAN + 828.240475353205*y_KAPANEWON_KOKAP + 366.82601749473076*y_KAPANEWON_KRETEK + 401.0770157299055*y_KAPANEWON_LENDAH + 323.9103919027395*y_KAPANEWON_MINGGIR + 583.1833797703109*y_KAPANEWON_MLATI + 954.4330851820833*y_KAPANEWON_MOYUDAN + 790.1807708725099*y_KAPANEWON_NANGGULAN + 198.8111135685725*y_KAPANEWON_NGAGLIK + 830.4310501300479*y_KAPANEWON_NGAWEN + 353.95732479714314*y_KAPANEWON_NGEMPLAK + 501.2248202641717*y_KAPANEWON_NGLIPAR + 840.5711247999247*y_KAPANEWON_PAJANGAN + 876.0053283891442*y_KAPANEWON_PAKEM + 227.34253062221998*y_KAPANEWON_PALIYAN + 256.9127053117688*y_KAPANEWON_PANDAK + 599.8537008118388*y_KAPANEWON_PANGGANG + 716.384495693622*y_KAPANEWON_PANJATAN + 195.04117410723643*y_KAPANEWON_PATUK + 581.8357772502195*y_KAPANEWON_PENGASIH + 989.7191306417087*y_KAPANEWON_PIYUNGAN + 858.3035158687652*y_KAPANEWON_PLAYEN + 804.2781342053229*y_KAPANEWON_PLERET + 128.83260423338072*y_KAPANEWON_PONJONG + 348.1740151166464*y_KAPANEWON_PRAMBANAN + 800.5346122424534*y_KAPANEWON_PUNDONG + 165.1254939417174*y_KAPANEWON_PURWOSARI + 208.00146019618182*y_KAPANEWON_RONGKOP + 809.7701841425662*y_KAPANEWON_SAMIGALUH + 163.38218757700196*y_KAPANEWON_SANDEN + 953.1005020461273*y_KAPANEWON_SAPTOSARI + 920.274102033204*y_KAPANEWON_SEDAYU + 426.30878229648107*y_KAPANEWON_SEMANU + 561.5283062564129*y_KAPANEWON_SEMIN + 979.3397748791798*y_KAPANEWON_SENTOLO + 555.7091967388552*y_KAPANEWON_SEWON + 93.40929249802554*y_KAPANEWON_SEYEGAN + 83.4546705028758*y_KAPANEWON_SLEMAN + 975.4081372822527*y_KAPANEWON_SRANDAKAN + 831.4319255729408*y_KAPANEWON_TANJUNGSARI + 993.5607030020788*y_KAPANEWON_TEMON + 973.4872828585156*y_KAPANEWON_TEMPEL + 416.1464021094501*y_KAPANEWON_TEPUS + 384.9954387169386*y_KAPANEWON_TURI + 249.63493267277414*y_KAPANEWON_WATES + 517.6495523661396*y_KAPANEWON_WONOSARI + 160.18333924957284*y_KEMANTREN_DANUREJAN + 366.8450925010993*y_KEMANTREN_GEDONGTENGEN + 271.79375192650326*y_KEMANTREN_GONDOKUSUMAN + 69.36084357166838*y_KEMANTREN_GONDOMANAN + 701.7777691207754*y_KEMANTREN_JETIS + 726.7676076099908*y_KEMANTREN_KOTAGEDE + 824.3551922128399*y_KEMANTREN_KRATON + 670.806728172877*y_KEMANTREN_MANTRIJERON + 588.305966673503*y_KEMANTREN_MERGANGSAN + 848.6391908129249*y_KEMANTREN_NGAMPILAN + 195.90732919891462*y_KEMANTREN_PAKUALAMAN + 810.2378151448871*y_KEMANTREN_TEGALREJO + 471.805619730545*y_KEMANTREN_UMBULHARJO + 43.360427299467204*y_KEMANTREN_WIROBRAJAN + 379.2433234429733*y_Kajoran + 804.547736336031*y_Kaliangkrik + 772.4905920673073*y_Kalikotes + 426.7257777010834*y_Karanganom + 924.34397622867*y_Karangdowo + 336.4401207805315*y_Karangnongko + 661.0874431741469*y_Kebonarum + 144.99185283929793*y_Kemalang + 614.7303958228715*y_Klaten_Selatan + 422.93067432092437*y_Klaten_Tengah + 577.2889778081338*y_Klaten_Utara + 360.4837619138056*y_Magelang_Selatan + 142.4845492652781*y_Magelang_Te ...
# VARIABLES
# 0 <= y_Bandongan <= 1 Integer
# 0 <= y_Bayat <= 1 Integer
# 0 <= y_Borobudur <= 1 Integer
# 0 <= y_Candimulyo <= 1 Integer
# 0 <= y_Cawas <= 1 Integer
# 0 <= y_Ceper <= 1 Integer
# 0 <= y_Delanggu <= 1 Integer
# 0 <= y_Dukun <= 1 Integer
# 0 <= y_Gantiwarno <= 1 Integer
# 0 <= y_Grabag <= 1 Integer
# 0 <= y_Jatinom <= 1 Integer
# 0 <= y_Jogonalan <= 1 Integer
# 0 <= y_Juwiring <= 1 Integer
# 0 <= y_KAPANEWON_BAMBANG_LIPURO <= 1 Integer
# 0 <= y_KAPANEWON_BANGUNTAPAN <= 1 Integer
# 0 <= y_KAPANEWON_BANTUL <= 1 Integer
# 0 <= y_KAPANEWON_BERBAH <= 1 Integer
# 0 <= y_KAPANEWON_CANGKRINGAN <= 1 Integer
# 0 <= y_KAPANEWON_DEPOK <= 1 Integer
# 0 <= y_KAPANEWON_DLINGO <= 1 Integer
# 0 <= y_KAPANEWON_GALUR <= 1 Integer
# 0 <= y_KAPANEWON_GAMPING <= 1 Integer
# 0 <= y_KAPANEWON_GEDANGSARI <= 1 Integer
# 0 <= y_KAPANEWON_GIRIMULYO <= 1 Integer
# 0 <= y_KAPANEWON_GIRISUBO <= 1 Integer
# 0 <= y_KAPANEWON_GODEAN <= 1 Integer
# 0 <= y_KAPANEWON_IMOGIRI <= 1 Integer
# 0 <= y_KAPANEWON_JETIS <= 1 Integer
# 0 <= y_KAPANEWON_KALASAN <= 1 Integer
# 0 <= y_KAPANEWON_KALIBAWANG <= 1 Integer
# 0 <= y_KAPANEWON_KARANGMOJO <= 1 Integer
# 0 <= y_KAPANEWON_KASIHAN <= 1 Integer
# 0 <= y_KAPANEWON_KOKAP <= 1 Integer
# 0 <= y_KAPANEWON_KRETEK <= 1 Integer
# 0 <= y_KAPANEWON_LENDAH <= 1 Integer
# 0 <= y_KAPANEWON_MINGGIR <= 1 Integer
# 0 <= y_KAPANEWON_MLATI <= 1 Integer
# 0 <= y_KAPANEWON_MOYUDAN <= 1 Integer
# 0 <= y_KAPANEWON_NANGGULAN <= 1 Integer
# 0 <= y_KAPANEWON_NGAGLIK <= 1 Integer
# 0 <= y_KAPANEWON_NGAWEN <= 1 Integer
# 0 <= y_KAPANEWON_NGEMPLAK <= 1 Integer
# 0 <= y_KAPANEWON_NGLIPAR <= 1 Integer
# 0 <= y_KAPANEWON_PAJANGAN <= 1 Integer
# 0 <= y_KAPANEWON_PAKEM <= 1 Integer
# 0 <= y_KAPANEWON_PALIYAN <= 1 Integer
# 0 <= y_KAPANEWON_PANDAK <= 1 Integer
# 0 <= y_KAPANEWON_PANGGANG <= 1 Integer
# 0 <= y_KAPANEWON_PANJATAN <= 1 Integer
# 0 <= y_KAPANEWON_PATUK <= 1 Integer
# 0 <= y_KAPANEWON_PENGASIH <= 1 Integer
# 0 <= y_KAPANEWON_PIYUNGAN <= 1 Integer
# 0 <= y_KAPANEWON_PLAYEN <= 1 Integer
# 0 <= y_KAPANEWON_PLERET <= 1 Integer
# 0 <= y_KAPANEWON_PONJONG <= 1 Integer
# 0 <= y_KAPANEWON_PRAMBANAN <= 1 Integer
# 0 <= y_KAPANEWON_PUNDONG <= 1 Integer
# 0 <= y_KAPANEWON_PURWOSARI <= 1 Integer
# 0 <= y_KAPANEWON_RONGKOP <= 1 Integer
# 0 <= y_KAPANEWON_SAMIGALUH <= 1 Integer
# 0 <= y_KAPANEWON_SANDEN <= 1 Integer
# 0 <= y_KAPANEWON_SAPTOSARI <= 1 Integer
# 0 <= y_KAPANEWON_SEDAYU <= 1 Integer
# 0 <= y_KAPANEWON_SEMANU <= 1 Integer
# 0 <= y_KAPANEWON_SEMIN <= 1 Integer
# 0 <= y_KAPANEWON_SENTOLO <= 1 Integer
# 0 <= y_KAPANEWON_SEWON <= 1 Integer
# 0 <= y_KAPANEWON_SEYEGAN <= 1 Integer
# 0 <= y_KAPANEWON_SLEMAN <= 1 Integer
# 0 <= y_KAPANEWON_SRANDAKAN <= 1 Integer
# 0 <= y_KAPANEWON_TANJUNGSARI <= 1 Integer
# 0 <= y_KAPANEWON_TEMON <= 1 Integer
# 0 <= y_KAPANEWON_TEMPEL <= 1 Integer
# 0 <= y_KAPANEWON_TEPUS <= 1 Integer
# 0 <= y_KAPANEWON_TURI <= 1 Integer
# 0 <= y_KAPANEWON_WATES <= 1 Integer
# 0 <= y_KAPANEWON_WONOSARI <= 1 Integer
# 0 <= y_KEMANTREN_DANUREJAN <= 1 Integer
# 0 <= y_KEMANTREN_GEDONGTENGEN <= 1 Integer
# 0 <= y_KEMANTREN_GONDOKUSUMAN <= 1 Integer
# 0 <= y_KEMANTREN_GONDOMANAN <= 1 Integer
# 0 <= y_KEMANTREN_JETIS <= 1 Integer
# 0 <= y_KEMANTREN_KOTAGEDE <= 1 Integer
# 0 <= y_KEMANTREN_KRATON <= 1 Integer
# 0 <= y_KEMANTREN_MANTRIJERON <= 1 Integer
# 0 <= y_KEMANTREN_MERGANGSAN <= 1 Integer
# 0 <= y_KEMANTREN_NGAMPILAN <= 1 Integer
# 0 <= y_KEMANTREN_PAKUALAMAN <= 1 Integer
# 0 <= y_KEMANTREN_TEGALREJO <= 1 Integer
# 0 <= y_KEMANTREN_UMBULHARJO <= 1 Integer
# 0 <= y_KEMANTREN_WIROBRAJAN <= 1 Integer
# 0 <= y_Kajoran <= 1 Integer
# 0 <= y_Kaliangkrik <= 1 Integer
# 0 <= y_Kalikotes <= 1 Integer
# 0 <= y_Karanganom <= 1 Integer
# 0 <= y_Karangdowo <= 1 Integer
# 0 <= y_Karangnongko <= 1 Integer
# 0 <= y_Kebonarum <= 1 Integer
# 0 <= y_Kemalang <= 1 Integer
# 0 <= y_Klaten_Selatan <= 1 Integer
# 0 <= y_Klaten_Tengah <= 1 Integer
# 0 <= y_Klaten_Utara <= 1 Integer
# 0 <= y_Magelang_Selatan <= 1 Integer
# 0 <= y_Magelang_Tengah <= 1 Integer
# 0 <= y_Magelang_Utara <= 1 Integer
# 0 <= y_Manisrenggo <= 1 Integer
# 0 <= y_Mertoyudan <= 1 Integer
# 0 <= y_Mungkid <= 1 Integer
# 0 <= y_Muntilan <= 1 Integer
# 0 <= y_Ngablak <= 1 Integer
# 0 <= y_Ngawen <= 1 Integer
# 0 <= y_Ngluwar <= 1 Integer
# 0 <= y_Pakis <= 1 Integer
# 0 <= y_Pedan <= 1 Integer
# 0 <= y_Polanharjo <= 1 Integer
# 0 <= y_Prambanan <= 1 Integer
# 0 <= y_Salam <= 1 Integer
# 0 <= y_Salaman <= 1 Integer
# 0 <= y_Sawangan <= 1 Integer
# 0 <= y_Secang <= 1 Integer
# 0 <= y_Srumbung <= 1 Integer
# 0 <= y_Tegalrejo <= 1 Integer
# 0 <= y_Tempuran <= 1 Integer
# 0 <= y_Trucuk <= 1 Integer
# 0 <= y_Tulung <= 1 Integer
# 0 <= y_Wedi <= 1 Integer
# 0 <= y_Windusari <= 1 Integer
# 0 <= y_Wonosari <= 1 Integer

# %%
# Set up constraints K (maximal SPKLU YANG DIBANGUN)
problem += pulp.lpSum([facility_open[f] for f in facilities]) == k

# %%
problem
# Out:
# MCLP:
# MAXIMIZE
# 589.8425549887097*y_Bandongan + 980.968821859348*y_Bayat + 586.2986719984674*y_Borobudur + 629.1994433433433*y_Candimulyo + 920.9271724989774*y_Cawas + 293.99446779335494*y_Ceper + 900.2234981668339*y_Delanggu + 322.61594735041666*y_Dukun + 121.40895106316829*y_Gantiwarno + 810.912528588859*y_Grabag + 963.0687045665818*y_Jatinom + 301.2064840143849*y_Jogonalan + 511.54252866204854*y_Juwiring + 559.9575368977414*y_KAPANEWON_BAMBANG_LIPURO + 363.4851455257291*y_KAPANEWON_BANGUNTAPAN + 963.5657054103127*y_KAPANEWON_BANTUL + 325.748664394955*y_KAPANEWON_BERBAH + 471.4036913074094*y_KAPANEWON_CANGKRINGAN + 316.3457972476483*y_KAPANEWON_DEPOK + 509.5108059553727*y_KAPANEWON_DLINGO + 693.0510815699544*y_KAPANEWON_GALUR + 643.9988809030568*y_KAPANEWON_GAMPING + 558.0080408057444*y_KAPANEWON_GEDANGSARI + 836.9982538015092*y_KAPANEWON_GIRIMULYO + 657.571223346218*y_KAPANEWON_GIRISUBO + 238.89131128752993*y_KAPANEWON_GODEAN + 332.3022880699811*y_KAPANEWON_IMOGIRI + 588.9180160669276*y_KAPANEWON_JETIS + 328.0971232962794*y_KAPANEWON_KALASAN + 87.69843009707668*y_KAPANEWON_KALIBAWANG + 491.5255943534368*y_KAPANEWON_KARANGMOJO + 943.0368326733397*y_KAPANEWON_KASIHAN + 828.240475353205*y_KAPANEWON_KOKAP + 366.82601749473076*y_KAPANEWON_KRETEK + 401.0770157299055*y_KAPANEWON_LENDAH + 323.9103919027395*y_KAPANEWON_MINGGIR + 583.1833797703109*y_KAPANEWON_MLATI + 954.4330851820833*y_KAPANEWON_MOYUDAN + 790.1807708725099*y_KAPANEWON_NANGGULAN + 198.8111135685725*y_KAPANEWON_NGAGLIK + 830.4310501300479*y_KAPANEWON_NGAWEN + 353.95732479714314*y_KAPANEWON_NGEMPLAK + 501.2248202641717*y_KAPANEWON_NGLIPAR + 840.5711247999247*y_KAPANEWON_PAJANGAN + 876.0053283891442*y_KAPANEWON_PAKEM + 227.34253062221998*y_KAPANEWON_PALIYAN + 256.9127053117688*y_KAPANEWON_PANDAK + 599.8537008118388*y_KAPANEWON_PANGGANG + 716.384495693622*y_KAPANEWON_PANJATAN + 195.04117410723643*y_KAPANEWON_PATUK + 581.8357772502195*y_KAPANEWON_PENGASIH + 989.7191306417087*y_KAPANEWON_PIYUNGAN + 858.3035158687652*y_KAPANEWON_PLAYEN + 804.2781342053229*y_KAPANEWON_PLERET + 128.83260423338072*y_KAPANEWON_PONJONG + 348.1740151166464*y_KAPANEWON_PRAMBANAN + 800.5346122424534*y_KAPANEWON_PUNDONG + 165.1254939417174*y_KAPANEWON_PURWOSARI + 208.00146019618182*y_KAPANEWON_RONGKOP + 809.7701841425662*y_KAPANEWON_SAMIGALUH + 163.38218757700196*y_KAPANEWON_SANDEN + 953.1005020461273*y_KAPANEWON_SAPTOSARI + 920.274102033204*y_KAPANEWON_SEDAYU + 426.30878229648107*y_KAPANEWON_SEMANU + 561.5283062564129*y_KAPANEWON_SEMIN + 979.3397748791798*y_KAPANEWON_SENTOLO + 555.7091967388552*y_KAPANEWON_SEWON + 93.40929249802554*y_KAPANEWON_SEYEGAN + 83.4546705028758*y_KAPANEWON_SLEMAN + 975.4081372822527*y_KAPANEWON_SRANDAKAN + 831.4319255729408*y_KAPANEWON_TANJUNGSARI + 993.5607030020788*y_KAPANEWON_TEMON + 973.4872828585156*y_KAPANEWON_TEMPEL + 416.1464021094501*y_KAPANEWON_TEPUS + 384.9954387169386*y_KAPANEWON_TURI + 249.63493267277414*y_KAPANEWON_WATES + 517.6495523661396*y_KAPANEWON_WONOSARI + 160.18333924957284*y_KEMANTREN_DANUREJAN + 366.8450925010993*y_KEMANTREN_GEDONGTENGEN + 271.79375192650326*y_KEMANTREN_GONDOKUSUMAN + 69.36084357166838*y_KEMANTREN_GONDOMANAN + 701.7777691207754*y_KEMANTREN_JETIS + 726.7676076099908*y_KEMANTREN_KOTAGEDE + 824.3551922128399*y_KEMANTREN_KRATON + 670.806728172877*y_KEMANTREN_MANTRIJERON + 588.305966673503*y_KEMANTREN_MERGANGSAN + 848.6391908129249*y_KEMANTREN_NGAMPILAN + 195.90732919891462*y_KEMANTREN_PAKUALAMAN + 810.2378151448871*y_KEMANTREN_TEGALREJO + 471.805619730545*y_KEMANTREN_UMBULHARJO + 43.360427299467204*y_KEMANTREN_WIROBRAJAN + 379.2433234429733*y_Kajoran + 804.547736336031*y_Kaliangkrik + 772.4905920673073*y_Kalikotes + 426.7257777010834*y_Karanganom + 924.34397622867*y_Karangdowo + 336.4401207805315*y_Karangnongko + 661.0874431741469*y_Kebonarum + 144.99185283929793*y_Kemalang + 614.7303958228715*y_Klaten_Selatan + 422.93067432092437*y_Klaten_Tengah + 577.2889778081338*y_Klaten_Utara + 360.4837619138056*y_Magelang_Selatan + 142.4845492652781*y_Magelang_Te ...
# SUBJECT TO
# _C1: x_Bandongan + x_Bayat + x_Borobudur + x_Candimulyo + x_Cawas + x_Ceper
#  + x_Delanggu + x_Dukun + x_Gantiwarno + x_Grabag + x_Jatinom + x_Jogonalan
#  + x_Juwiring + x_KAPANEWON_BAMBANG_LIPURO + x_KAPANEWON_BANGUNTAPAN
#  + x_KAPANEWON_BANTUL + x_KAPANEWON_BERBAH + x_KAPANEWON_CANGKRINGAN
#  + x_KAPANEWON_DEPOK + x_KAPANEWON_DLINGO + x_KAPANEWON_GALUR
#  + x_KAPANEWON_GAMPING + x_KAPANEWON_GEDANGSARI + x_KAPANEWON_GIRIMULYO
#  + x_KAPANEWON_GIRISUBO + x_KAPANEWON_GODEAN + x_KAPANEWON_IMOGIRI
#  + x_KAPANEWON_JETIS + x_KAPANEWON_KALASAN + x_KAPANEWON_KALIBAWANG
#  + x_KAPANEWON_KARANGMOJO + x_KAPANEWON_KASIHAN + x_KAPANEWON_KOKAP
#  + x_KAPANEWON_KRETEK + x_KAPANEWON_LENDAH + x_KAPANEWON_MINGGIR
#  + x_KAPANEWON_MLATI + x_KAPANEWON_MOYUDAN + x_KAPANEWON_NANGGULAN
#  + x_KAPANEWON_NGAGLIK + x_KAPANEWON_NGAWEN + x_KAPANEWON_NGEMPLAK
#  + x_KAPANEWON_NGLIPAR + x_KAPANEWON_PAJANGAN + x_KAPANEWON_PAKEM
#  + x_KAPANEWON_PALIYAN + x_KAPANEWON_PANDAK + x_KAPANEWON_PANGGANG
#  + x_KAPANEWON_PANJATAN + x_KAPANEWON_PATUK + x_KAPANEWON_PENGASIH
#  + x_KAPANEWON_PIYUNGAN + x_KAPANEWON_PLAYEN + x_KAPANEWON_PLERET
#  + x_KAPANEWON_PONJONG + x_KAPANEWON_PRAMBANAN + x_KAPANEWON_PUNDONG
#  + x_KAPANEWON_PURWOSARI + x_KAPANEWON_RONGKOP + x_KAPANEWON_SAMIGALUH
#  + x_KAPANEWON_SANDEN + x_KAPANEWON_SAPTOSARI + x_KAPANEWON_SEDAYU
#  + x_KAPANEWON_SEMANU + x_KAPANEWON_SEMIN + x_KAPANEWON_SENTOLO
#  + x_KAPANEWON_SEWON + x_KAPANEWON_SEYEGAN + x_KAPANEWON_SLEMAN
#  + x_KAPANEWON_SRANDAKAN + x_KAPANEWON_TANJUNGSARI + x_KAPANEWON_TEMON
#  + x_KAPANEWON_TEMPEL + x_KAPANEWON_TEPUS + x_KAPANEWON_TURI
#  + x_KAPANEWON_WATES + x_KAPANEWON_WONOSARI + x_KEMANTREN_DANUREJAN
#  + x_KEMANTREN_GEDONGTENGEN + x_KEMANTREN_GONDOKUSUMAN
#  + x_KEMANTREN_GONDOMANAN + x_KEMANTREN_JETIS + x_KEMANTREN_KOTAGEDE
#  + x_KEMANTREN_KRATON + x_KEMANTREN_MANTRIJERON + x_KEMANTREN_MERGANGSAN
#  + x_KEMANTREN_NGAMPILAN + x_KEMANTREN_PAKUALAMAN + x_KEMANTREN_TEGALREJO
#  + x_KEMANTREN_UMBULHARJO + x_KEMANTREN_WIROBRAJAN + x_Kajoran + x_Kaliangkrik
#  + x_Kalikotes + x_Karanganom + x_Karangdowo + x_Karangnongko + x_Kebonarum
#  + x_Kemalang + x_Klaten_Selatan + x_Klaten_Tengah + x_Klaten_Utara
#  + x_Magelang_Selatan + x_Magelang_Tengah + x_Magelang_Utara + x_Manisrenggo
#  + x_Mertoyudan + x_Mungkid + x_Muntilan + x_Ngablak + x_Ngawen + x_Ngluwar
#  + x_Pakis + x_Pedan + x_Polanharjo + x_Prambanan + x_Salam + x_Salaman
#  + x_Sawangan + x_Secang + x_Srumbung + x_Tegalrejo + x_Tempuran + x_Trucuk
#  + x_Tulung + x_Wedi + x_Windusari + x_Wonosari = 3
#
# VARIABLES
# 0 <= x_Bandongan <= 1 Integer
# 0 <= x_Bayat <= 1 Integer
# 0 <= x_Borobudur <= 1 Integer
# 0 <= x_Candimulyo <= 1 Integer
# 0 <= x_Cawas <= 1 Integer
# 0 <= x_Ceper <= 1 Integer
# 0 <= x_Delanggu <= 1 Integer
# 0 <= x_Dukun <= 1 Integer
# 0 <= x_Gantiwarno <= 1 Integer
# 0 <= x_Grabag <= 1 Integer
# 0 <= x_Jatinom <= 1 Integer
# 0 <= x_Jogonalan <= 1 Integer
# 0 <= x_Juwiring <= 1 Integer
# 0 <= x_KAPANEWON_BAMBANG_LIPURO <= 1 Integer
# 0 <= x_KAPANEWON_BANGUNTAPAN <= 1 Integer
# 0 <= x_KAPANEWON_BANTUL <= 1 Integer
# 0 <= x_KAPANEWON_BERBAH <= 1 Integer
# 0 <= x_KAPANEWON_CANGKRINGAN <= 1 Integer
# 0 <= x_KAPANEWON_DEPOK <= 1 Integer
# 0 <= x_KAPANEWON_DLINGO <= 1 Integer
# 0 <= x_KAPANEWON_GALUR <= 1 Integer
# 0 <= x_KAPANEWON_GAMPING <= 1 Integer
# 0 <= x_KAPANEWON_GEDANGSARI <= 1 Integer
# 0 <= x_KAPANEWON_GIRIMULYO <= 1 Integer
# 0 <= x_KAPANEWON_GIRISUBO <= 1 Integer
# 0 <= x_KAPANEWON_GODEAN <= 1 Integer
# 0 <= x_KAPANEWON_IMOGIRI <= 1 Integer
# 0 <= x_KAPANEWON_JETIS <= 1 Integer
# 0 <= x_KAPANEWON_KALASAN <= 1 Integer
# 0 <= x_KAPANEWON_KALIBAWANG <= 1 Integer
# 0 <= x_KAPANEWON_KARANGMOJO <= 1 Integer
# 0 <= x_KAPANEWON_KASIHAN <= 1 Integer
# 0 <= x_KAPANEWON_KOKAP <= 1 Integer
# 0 <= x_KAPANEWON_KRETEK <= 1 Integer
# 0 <= x_KAPANEWON_LENDAH <= 1 Integer
# 0 <= x_KAPANEWON_MINGGIR <= 1 Integer
# 0 <= x_KAPANEWON_MLATI <= 1 Integer
# 0 <= x_KAPANEWON_MOYUDAN <= 1 Integer
# 0 <= x_KAPANEWON_NANGGULAN <= 1 Integer
# 0 <= x_KAPANEWON_NGAGLIK <= 1 Integer
# 0 <= x_KAPANEWON_NGAWEN <= 1 Integer
# 0 <= x_KAPANEWON_NGEMPLAK <= 1 Integer
# 0 <= x_KAPANEWON_NGLIPAR <= 1 Integer
# 0 <= x_KAPANEWON_PAJANGAN <= 1 Integer
# 0 <= x_KAPANEWON_PAKEM <= 1 Integer
# 0 <= x_KAPANEWON_PALIYAN <= 1 Integer
# 0 <= x_KAPANEWON_PANDAK <= 1 Integer
# 0 <= x_KAPANEWON_PANGGANG <= 1 Integer
# 0 <= x_KAPANEWON_PANJATAN <= 1 Integer
# 0 <= x_KAPANEWON_PATUK <= 1 Integer
# 0 <= x_KAPANEWON_PENGASIH <= 1 Integer
# 0 <= x_KAPANEWON_PIYUNGAN <= 1 Integer
# 0 <= x_KAPANEWON_PLAYEN <= 1 Integer
# 0 <= x_KAPANEWON_PLERET <= 1 Integer
# 0 <= x_KAPANEWON_PONJONG <= 1 Integer
# 0 <= x_KAPANEWON_PRAMBANAN <= 1 Integer
# 0 <= x_KAPANEWON_PUNDONG <= 1 Integer
# 0 <= x_KAPANEWON_PURWOSARI <= 1 Integer
# 0 <= x_KAPANEWON_RONGKOP <= 1 Integer
# 0 <= x_KAPANEWON_SAMIGALUH <= 1 Integer
# 0 <= x_KAPANEWON_SANDEN <= 1 Integer
# 0 <= x_KAPANEWON_SAPTOSARI <= 1 Integer
# 0 <= x_KAPANEWON_SEDAYU <= 1 Integer
# 0 <= x_KAPANEWON_SEMANU <= 1 Integer
# 0 <= x_KAPANEWON_SEMIN <= 1 Integer
# 0 <= x_KAPANEWON_SENTOLO <= 1 Integer
# 0 <= x_KAPANEWON_SEWON <= 1 Integer
# 0 <= x_KAPANEWON_SEYEGAN <= 1 Integer
# 0 <= x_KAPANEWON_SLEMAN <= 1 Integer
# 0 <= x_KAPANEWON_SRANDAKAN <= 1 Integer
# 0 <= x_KAPANEWON_TANJUNGSARI <= 1 Integer
# 0 <= x_KAPANEWON_TEMON <= 1 Integer
# 0 <= x_KAPANEWON_TEMPEL <= 1 Integer
# 0 <= x_KAPANEWON_TEPUS <= 1 Integer
# 0 <= x_KAPANEWON_TURI <= 1 Integer
# 0 <= x_KAPANEWON_WATES <= 1 Integer
# 0 <= x_KAPANEWON_WONOSARI <= 1 Integer
# 0 <= x_KEMANTREN_DANUREJAN <= 1 Integer
# 0 <= x_KEMANTREN_GEDONGTENGEN <= 1 Integer
# 0 <= x_KEMANTREN_GONDOKUSUMAN <= 1 Integer
# 0 <= x_KEMANTREN_GONDOMANAN <= 1 Integer
# 0 <= x_KEMANTREN_JETIS <= 1 Integer
# 0 <= x_KEMANTREN_KOTAGEDE <= 1 Integer
# 0 <= x_KEMANTREN_KRATON <= 1 Integer
# 0 <= x_KEMANTREN_MANTRIJERON <= 1 Integer
# 0 <= x_KEMANTREN_MERGANGSAN <= 1 Integer
# 0 <= x_KEMANTREN_NGAMPILAN <= 1 Integer
# 0 <= x_KEMANTREN_PAKUALAMAN <= 1 Integer
# 0 <= x_KEMANTREN_TEGALREJO <= 1 Integer
# 0 <= x_KEMANTREN_UMBULHARJO <= 1 Integer
# 0 <= x_KEMANTREN_WIROBRAJAN <= 1 Integer
# 0 <= x_Kajoran <= 1 Integer
# 0 <= x_Kaliangkrik <= 1 Integer
# 0 <= x_Kalikotes <= 1 Integer
# 0 <= x_Karanganom <= 1 Integer
# 0 <= x_Karangdowo <= 1 Integer
# 0 <= x_Karangnongko <= 1 Integer
# 0 <= x_Kebonarum <= 1 Integer
# 0 <= x_Kemalang <= 1 Integer
# 0 <= x_Klaten_Selatan <= 1 Integer
# 0 <= x_Klaten_Tengah <= 1 Integer
# 0 <= x_Klaten_Utara <= 1 Integer
# 0 <= x_Magelang_Selatan <= 1 Integer
# 0 <= x_Magelang_Tengah <= 1 Integer
# 0 <= x_Magelang_Utara <= 1 Integer
# 0 <= x_Manisrenggo <= 1 Integer
# 0 <= x_Mertoyudan <= 1 Integer
# 0 <= x_Mungkid <= 1 Integer
# 0 <= x_Muntilan <= 1 Integer
# 0 <= x_Ngablak <= 1 Integer
# 0 <= x_Ngawen <= 1 Integer
# 0 <= x_Ngluwar <= 1 Integer
# 0 <= x_Pakis <= 1 Integer
# 0 <= x_Pedan <= 1 Integer
# 0 <= x_Polanharjo <= 1 Integer
# 0 <= x_Prambanan <= 1 Integer
# 0 <= x_Salam <= 1 Integer
# 0 <= x_Salaman <= 1 Integer
# 0 <= x_Sawangan <= 1 Integer
# 0 <= x_Secang <= 1 Integer
# 0 <= x_Srumbung <= 1 Integer
# 0 <= x_Tegalrejo <= 1 Integer
# 0 <= x_Tempuran <= 1 Integer
# 0 <= x_Trucuk <= 1 Integer
# 0 <= x_Tulung <= 1 Integer
# 0 <= x_Wedi <= 1 Integer
# 0 <= x_Windusari <= 1 Integer
# 0 <= x_Wonosari <= 1 Integer
# 0 <= y_Bandongan <= 1 Integer
# 0 <= y_Bayat <= 1 Integer
# 0 <= y_Borobudur <= 1 Integer
# 0 <= y_Candimulyo <= 1 Integer
# 0 <= y_Cawas <= 1 Integer
# 0 <= y_Ceper <= 1 Integer
# 0 <= y_Delanggu <= 1 Integer
# 0 <= y_Dukun <= 1 Integer
# 0 <= y_Gantiwarno <= 1 Integer
# 0 <= y_Grabag <= 1 Integer
# 0 <= y_Jatinom <= 1 Integer
# 0 <= y_Jogonalan <= 1 Integer
# 0 <= y_Juwiring <= 1 Integer
# 0 <= y_KAPANEWON_BAMBANG_LIPURO <= 1 Integer
# 0 <= y_KAPANEWON_BANGUNTAPAN <= 1 Integer
# 0 <= y_KAPANEWON_BANTUL <= 1 Integer
# 0 <= y_KAPANEWON_BERBAH <= 1 Integer
# 0 <= y_KAPANEWON_CANGKRINGAN <= 1 Integer
# 0 <= y_KAPANEWON_DEPOK <= 1 Integer
# 0 <= y_KAPANEWON_DLINGO <= 1 Integer
# 0 <= y_KAPANEWON_GALUR <= 1 Integer
# 0 <= y_KAPANEWON_GAMPING <= 1 Integer
# 0 <= y_KAPANEWON_GEDANGSARI <= 1 Integer
# 0 <= y_KAPANEWON_GIRIMULYO <= 1 Integer
# 0 <= y_KAPANEWON_GIRISUBO <= 1 Integer
# 0 <= y_KAPANEWON_GODEAN <= 1 Integer
# 0 <= y_KAPANEWON_IMOGIRI <= 1 Integer
# 0 <= y_KAPANEWON_JETIS <= 1 Integer
# 0 <= y_KAPANEWON_KALASAN <= 1 Integer
# 0 <= y_KAPANEWON_KALIBAWANG <= 1 Integer
# 0 <= y_KAPANEWON_KARANGMOJO <= 1 Integer
# 0 <= y_KAPANEWON_KASIHAN <= 1 Integer
# 0 <= y_KAPANEWON_KOKAP <= 1 Integer
# 0 <= y_KAPANEWON_KRETEK <= 1 Integer
# 0 <= y_KAPANEWON_LENDAH <= 1 Integer
# 0 <= y_KAPANEWON_MINGGIR <= 1 Integer
# 0 <= y_KAPANEWON_MLATI <= 1 Integer
# 0 <= y_KAPANEWON_MOYUDAN <= 1 Integer
# 0 <= y_KAPANEWON_NANGGULAN <= 1 Integer
# 0 <= y_KAPANEWON_NGAGLIK <= 1 Integer
# 0 <= y_KAPANEWON_NGAWEN <= 1 Integer
# 0 <= y_KAPANEWON_NGEMPLAK <= 1 Integer
# 0 <= y_KAPANEWON_NGLIPAR <= 1 Integer
# 0 <= y_KAPANEWON_PAJANGAN <= 1 Integer
# 0 <= y_KAPANEWON_PAKEM <= 1 Integer
# 0 <= y_KAPANEWON_PALIYAN <= 1 Integer
# 0 <= y_KAPANEWON_PANDAK <= 1 Integer
# 0 <= y_KAPANEWON_PANGGANG <= 1 Integer
# 0 <= y_KAPANEWON_PANJATAN <= 1 Integer
# 0 <= y_KAPANEWON_PATUK <= 1 Integer
# 0 <= y_KAPANEWON_PENGASIH <= 1 Integer
# 0 <= y_KAPANEWON_PIYUNGAN <= 1 Integer
# 0 <= y_KAPANEWON_PLAYEN <= 1 Integer
# 0 <= y_KAPANEWON_PLERET <= 1 Integer
# 0 <= y_KAPANEWON_PONJONG <= 1 Integer
# 0 <= y_KAPANEWON_PRAMBANAN <= 1 Integer
# 0 <= y_KAPANEWON_PUNDONG <= 1 Integer
# 0 <= y_KAPANEWON_PURWOSARI <= 1 Integer
# 0 <= y_KAPANEWON_RONGKOP <= 1 Integer
# 0 <= y_KAPANEWON_SAMIGALUH <= 1 Integer
# 0 <= y_KAPANEWON_SANDEN <= 1 Integer
# 0 <= y_KAPANEWON_SAPTOSARI <= 1 Integer
# 0 <= y_KAPANEWON_SEDAYU <= 1 Integer
# 0 <= y_KAPANEWON_SEMANU <= 1 Integer
# 0 <= y_KAPANEWON_SEMIN <= 1 Integer
# 0 <= y_KAPANEWON_SENTOLO <= 1 Integer
# 0 <= y_KAPANEWON_SEWON <= 1 Integer
# 0 <= y_KAPANEWON_SEYEGAN <= 1 Integer
# 0 <= y_KAPANEWON_SLEMAN <= 1 Integer
# 0 <= y_KAPANEWON_SRANDAKAN <= 1 Integer
# 0 <= y_KAPANEWON_TANJUNGSARI <= 1 Integer
# 0 <= y_KAPANEWON_TEMON <= 1 Integer
# 0 <= y_KAPANEWON_TEMPEL <= 1 Integer
# 0 <= y_KAPANEWON_TEPUS <= 1 Integer
# 0 <= y_KAPANEWON_TURI <= 1 Integer
# 0 <= y_KAPANEWON_WATES <= 1 Integer
# 0 <= y_KAPANEWON_WONOSARI <= 1 Integer
# 0 <= y_KEMANTREN_DANUREJAN <= 1 Integer
# 0 <= y_KEMANTREN_GEDONGTENGEN <= 1 Integer
# 0 <= y_KEMANTREN_GONDOKUSUMAN <= 1 Integer
# 0 <= y_KEMANTREN_GONDOMANAN <= 1 Integer
# 0 <= y_KEMANTREN_JETIS <= 1 Integer
# 0 <= y_KEMANTREN_KOTAGEDE <= 1 Integer
# 0 <= y_KEMANTREN_KRATON <= 1 Integer
# 0 <= y_KEMANTREN_MANTRIJERON <= 1 Integer
# 0 <= y_KEMANTREN_MERGANGSAN <= 1 Integer
# 0 <= y_KEMANTREN_NGAMPILAN <= 1 Integer
# 0 <= y_KEMANTREN_PAKUALAMAN <= 1 Integer
# 0 <= y_KEMANTREN_TEGALREJO <= 1 Integer
# 0 <= y_KEMANTREN_UMBULHARJO <= 1 Integer
# 0 <= y_KEMANTREN_WIROBRAJAN <= 1 Integer
# 0 <= y_Kajoran <= 1 Integer
# 0 <= y_Kaliangkrik <= 1 Integer
# 0 <= y_Kalikotes <= 1 Integer
# 0 <= y_Karanganom <= 1 Integer
# 0 <= y_Karangdowo <= 1 Integer
# 0 <= y_Karangnongko <= 1 Integer
# 0 <= y_Kebonarum <= 1 Integer
# 0 <= y_Kemalang <= 1 Integer
# 0 <= y_Klaten_Selatan <= 1 Integer
# 0 <= y_Klaten_Tengah <= 1 Integer
# 0 <= y_Klaten_Utara <= 1 Integer
# 0 <= y_Magelang_Selatan <= 1 Integer
# 0 <= y_Magelang_Tengah <= 1 Integer
# 0 <= y_Magelang_Utara <= 1 Integer
# 0 <= y_Manisrenggo <= 1 Integer
# 0 <= y_Mertoyudan <= 1 Integer
# 0 <= y_Mungkid <= 1 Integer
# 0 <= y_Muntilan <= 1 Integer
# 0 <= y_Ngablak <= 1 Integer
# 0 <= y_Ngawen <= 1 Integer
# 0 <= y_Ngluwar <= 1 Integer
# 0 <= y_Pakis <= 1 Integer
# 0 <= y_Pedan <= 1 Integer
# 0 <= y_Polanharjo <= 1 Integer
# 0 <= y_Prambanan <= 1 Integer
# 0 <= y_Salam <= 1 Integer
# 0 <= y_Salaman <= 1 Integer
# 0 <= y_Sawangan <= 1 Integer
# 0 <= y_Secang <= 1 Integer
# 0 <= y_Srumbung <= 1 Integer
# 0 <= y_Tegalrejo <= 1 Integer
# 0 <= y_Tempuran <= 1 Integer
# 0 <= y_Trucuk <= 1 Integer
# 0 <= y_Tulung <= 1 Integer
# 0 <= y_Wedi <= 1 Integer
# 0 <= y_Windusari <= 1 Integer
# 0 <= y_Wonosari <= 1 Integer

# %%
N = [[j for j in facilities if df[i][j] <= maximum_coverage] for i in demand_points]

# N = {i:[j for j in facilities if df[i][j] <= 10000] for i in demand_points}
N
# Out:
# [['KAPANEWON TEMON', 'KAPANEWON WATES', 'KAPANEWON KOKAP'],
#  ['KAPANEWON TEMON',
#   'KAPANEWON WATES',
#   'KAPANEWON PANJATAN',
#   'KAPANEWON PENGASIH'],
#  ['KAPANEWON WATES',
#   'KAPANEWON PANJATAN',
#   'KAPANEWON GALUR',
#   'KAPANEWON LENDAH',
#   'KAPANEWON PENGASIH'],
#  ['KAPANEWON PANJATAN',
#   'KAPANEWON GALUR',
#   'KAPANEWON LENDAH',
#   'KAPANEWON SRANDAKAN',
#   'KAPANEWON SANDEN',
#   'KAPANEWON BAMBANG LIPURO',
#   'KAPANEWON PANDAK'],
#  ['KAPANEWON PANJATAN',
#   'KAPANEWON GALUR',
#   'KAPANEWON LENDAH',
#   'KAPANEWON SRANDAKAN',
#   'KAPANEWON SANDEN',
#   'KAPANEWON BAMBANG LIPURO',
#   'KAPANEWON PANDAK'],
#  ['KAPANEWON SENTOLO', 'KAPANEWON PENGASIH', 'KAPANEWON SEDAYU'],
#  ['KAPANEWON WATES',
#   'KAPANEWON PANJATAN',
#   'KAPANEWON SENTOLO',
#   'KAPANEWON PENGASIH'],
#  ['KAPANEWON TEMON', 'KAPANEWON KOKAP'],
#  ['KAPANEWON GIRIMULYO', 'KAPANEWON NANGGULAN'],
#  ['KAPANEWON GIRIMULYO',
#   'KAPANEWON NANGGULAN',
#   'KAPANEWON MOYUDAN',
#   'KAPANEWON MINGGIR'],
#  ['KAPANEWON SAMIGALUH'],
#  ['KAPANEWON KALIBAWANG', 'KAPANEWON MINGGIR', 'Ngluwar', 'Salam'],
#  ['KAPANEWON GALUR',
#   'KAPANEWON LENDAH',
#   'KAPANEWON SRANDAKAN',
#   'KAPANEWON SANDEN',
#   'KAPANEWON BAMBANG LIPURO',
#   'KAPANEWON PANDAK'],
#  ['KAPANEWON GALUR',
#   'KAPANEWON LENDAH',
#   'KAPANEWON SRANDAKAN',
#   'KAPANEWON SANDEN',
#   'KAPANEWON KRETEK',
#   'KAPANEWON BAMBANG LIPURO',
#   'KAPANEWON PANDAK'],
#  ['KAPANEWON SANDEN',
#   'KAPANEWON KRETEK',
#   'KAPANEWON PUNDONG',
#   'KAPANEWON BAMBANG LIPURO'],
#  ['KAPANEWON KRETEK',
#   'KAPANEWON PUNDONG',
#   'KAPANEWON BAMBANG LIPURO',
#   'KAPANEWON JETIS',
#   'KAPANEWON IMOGIRI',
#   'KAPANEWON PURWOSARI'],
#  ['KAPANEWON GALUR',
#   'KAPANEWON LENDAH',
#   'KAPANEWON SRANDAKAN',
#   'KAPANEWON SANDEN',
#   'KAPANEWON KRETEK',
#   'KAPANEWON PUNDONG',
#   'KAPANEWON BAMBANG LIPURO',
#   'KAPANEWON PANDAK',
#   'KAPANEWON BANTUL'],
#  ['KAPANEWON GALUR',
#   'KAPANEWON LENDAH',
#   'KAPANEWON SRANDAKAN',
#   'KAPANEWON SANDEN',
#   'KAPANEWON BAMBANG LIPURO',
#   'KAPANEWON PANDAK',
#   'KAPANEWON PAJANGAN',
#   'KAPANEWON BANTUL',
#   'KAPANEWON JETIS',
#   'KAPANEWON IMOGIRI'],
#  ['KAPANEWON PANDAK',
#   'KAPANEWON PAJANGAN',
#   'KAPANEWON BANTUL',
#   'KAPANEWON SEDAYU'],
#  ['KAPANEWON BAMBANG LIPURO',
#   'KAPANEWON PANDAK',
#   'KAPANEWON PAJANGAN',
#   'KAPANEWON BANTUL',
#   'KAPANEWON JETIS',
#   'KAPANEWON IMOGIRI',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON'],
#  ['KAPANEWON PUNDONG',
#   'KAPANEWON PANDAK',
#   'KAPANEWON BANTUL',
#   'KAPANEWON JETIS',
#   'KAPANEWON IMOGIRI',
#   'KAPANEWON PLERET',
#   'KAPANEWON SEWON',
#   'KEMANTREN MERGANGSAN'],
#  ['KAPANEWON PUNDONG',
#   'KAPANEWON PANDAK',
#   'KAPANEWON BANTUL',
#   'KAPANEWON JETIS',
#   'KAPANEWON IMOGIRI',
#   'KAPANEWON PLERET'],
#  ['KAPANEWON DLINGO'],
#  ['KAPANEWON BANGUNTAPAN',
#   'KAPANEWON PLERET',
#   'KAPANEWON PIYUNGAN',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON BERBAH',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON JETIS',
#   'KAPANEWON IMOGIRI',
#   'KAPANEWON BANGUNTAPAN',
#   'KAPANEWON PLERET',
#   'KAPANEWON SEWON',
#   'KAPANEWON BERBAH',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON BANGUNTAPAN',
#   'KAPANEWON PIYUNGAN',
#   'KAPANEWON PATUK',
#   'KAPANEWON BERBAH',
#   'KAPANEWON PRAMBANAN',
#   'KAPANEWON KALASAN'],
#  ['KAPANEWON BANTUL',
#   'KAPANEWON JETIS',
#   'KAPANEWON BANGUNTAPAN',
#   'KAPANEWON PLERET',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON BANTUL',
#   'KAPANEWON BANGUNTAPAN',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON SENTOLO',
#   'KAPANEWON PAJANGAN',
#   'KAPANEWON SEDAYU',
#   'KAPANEWON GAMPING',
#   'KAPANEWON GODEAN',
#   'KAPANEWON MOYUDAN'],
#  ['KAPANEWON WONOSARI',
#   'KAPANEWON PLAYEN',
#   'KAPANEWON SEMANU',
#   'KAPANEWON KARANGMOJO'],
#  ['KAPANEWON NGLIPAR'],
#  ['KAPANEWON WONOSARI', 'KAPANEWON PLAYEN', 'KAPANEWON PALIYAN'],
#  ['KAPANEWON PIYUNGAN', 'KAPANEWON PATUK'],
#  ['KAPANEWON PLAYEN', 'KAPANEWON PALIYAN', 'KAPANEWON SAPTOSARI'],
#  ['KAPANEWON PANGGANG', 'KAPANEWON PURWOSARI'],
#  ['KAPANEWON TEPUS', 'KAPANEWON TANJUNGSARI'],
#  ['KAPANEWON WONOSARI',
#   'KAPANEWON SEMANU',
#   'KAPANEWON KARANGMOJO',
#   'KAPANEWON PONJONG'],
#  ['KAPANEWON WONOSARI',
#   'KAPANEWON SEMANU',
#   'KAPANEWON KARANGMOJO',
#   'KAPANEWON PONJONG'],
#  ['KAPANEWON SEMANU', 'KAPANEWON KARANGMOJO', 'KAPANEWON PONJONG'],
#  ['KAPANEWON RONGKOP', 'KAPANEWON GIRISUBO'],
#  ['KAPANEWON SEMIN', 'KAPANEWON NGAWEN'],
#  ['KAPANEWON SEMIN', 'KAPANEWON NGAWEN'],
#  ['KAPANEWON GEDANGSARI'],
#  ['KAPANEWON PALIYAN', 'KAPANEWON SAPTOSARI'],
#  ['KAPANEWON RONGKOP', 'KAPANEWON GIRISUBO'],
#  ['KAPANEWON TEPUS', 'KAPANEWON TANJUNGSARI'],
#  ['KAPANEWON PUNDONG', 'KAPANEWON PANGGANG', 'KAPANEWON PURWOSARI'],
#  ['KAPANEWON KASIHAN',
#   'KAPANEWON SEDAYU',
#   'KAPANEWON GAMPING',
#   'KAPANEWON GODEAN',
#   'KAPANEWON MOYUDAN',
#   'KAPANEWON MLATI',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON SEDAYU',
#   'KAPANEWON GAMPING',
#   'KAPANEWON GODEAN',
#   'KAPANEWON MOYUDAN',
#   'KAPANEWON SEYEGAN',
#   'KAPANEWON MLATI',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN'],
#  ['KAPANEWON NANGGULAN',
#   'KAPANEWON SEDAYU',
#   'KAPANEWON GAMPING',
#   'KAPANEWON GODEAN',
#   'KAPANEWON MOYUDAN',
#   'KAPANEWON MINGGIR'],
#  ['KAPANEWON NANGGULAN',
#   'KAPANEWON KALIBAWANG',
#   'KAPANEWON MOYUDAN',
#   'KAPANEWON MINGGIR',
#   'KAPANEWON SEYEGAN'],
#  ['KAPANEWON GODEAN',
#   'KAPANEWON MINGGIR',
#   'KAPANEWON SEYEGAN',
#   'KAPANEWON MLATI',
#   'KAPANEWON SLEMAN',
#   'KAPANEWON TEMPEL'],
#  ['KAPANEWON GAMPING',
#   'KAPANEWON GODEAN',
#   'KAPANEWON SEYEGAN',
#   'KAPANEWON MLATI',
#   'KAPANEWON DEPOK',
#   'KAPANEWON SLEMAN',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GEDONGTENGEN'],
#  ['KAPANEWON MLATI',
#   'KAPANEWON DEPOK',
#   'KAPANEWON NGAGLIK',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO'],
#  ['KAPANEWON BANGUNTAPAN',
#   'KAPANEWON PLERET',
#   'KAPANEWON PIYUNGAN',
#   'KAPANEWON BERBAH',
#   'KAPANEWON PRAMBANAN',
#   'KAPANEWON KALASAN',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE',
#   'Prambanan'],
#  ['KAPANEWON PIYUNGAN',
#   'KAPANEWON BERBAH',
#   'KAPANEWON PRAMBANAN',
#   'KAPANEWON KALASAN',
#   'Gantiwarno',
#   'Jogonalan',
#   'Klaten Selatan',
#   'Prambanan'],
#  ['KAPANEWON PIYUNGAN',
#   'KAPANEWON BERBAH',
#   'KAPANEWON PRAMBANAN',
#   'KAPANEWON KALASAN',
#   'Gantiwarno',
#   'Prambanan'],
#  ['KAPANEWON NGEMPLAK',
#   'KAPANEWON NGAGLIK',
#   'KAPANEWON PAKEM',
#   'KAPANEWON CANGKRINGAN',
#   'Manisrenggo',
#   'Prambanan'],
#  ['KAPANEWON DEPOK',
#   'KAPANEWON NGEMPLAK',
#   'KAPANEWON NGAGLIK',
#   'KAPANEWON PAKEM',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'Manisrenggo'],
#  ['KAPANEWON SEYEGAN',
#   'KAPANEWON MLATI',
#   'KAPANEWON SLEMAN',
#   'KAPANEWON TEMPEL',
#   'KAPANEWON TURI'],
#  ['KAPANEWON SEYEGAN',
#   'KAPANEWON SLEMAN',
#   'KAPANEWON TEMPEL',
#   'KAPANEWON TURI'],
#  ['KAPANEWON SLEMAN',
#   'KAPANEWON TEMPEL',
#   'KAPANEWON TURI',
#   'KAPANEWON PAKEM',
#   'Kemalang'],
#  ['KAPANEWON NGEMPLAK',
#   'KAPANEWON NGAGLIK',
#   'KAPANEWON TURI',
#   'KAPANEWON PAKEM',
#   'KAPANEWON CANGKRINGAN',
#   'Kemalang',
#   'Manisrenggo'],
#  ['KAPANEWON NGEMPLAK',
#   'KAPANEWON PAKEM',
#   'KAPANEWON CANGKRINGAN',
#   'Karangnongko',
#   'Manisrenggo'],
#  ['KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KAPANEWON GODEAN',
#   'KAPANEWON MLATI',
#   'KAPANEWON DEPOK',
#   'KAPANEWON NGAGLIK',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KAPANEWON GODEAN',
#   'KAPANEWON MLATI',
#   'KAPANEWON DEPOK',
#   'KAPANEWON NGAGLIK',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON BANGUNTAPAN',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KAPANEWON DEPOK',
#   'KAPANEWON BERBAH',
#   'KAPANEWON NGAGLIK',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON BANGUNTAPAN',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KAPANEWON DEPOK',
#   'KAPANEWON BERBAH',
#   'KAPANEWON NGAGLIK',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KAPANEWON GODEAN',
#   'KAPANEWON DEPOK',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON BANTUL',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KAPANEWON GODEAN',
#   'KAPANEWON DEPOK',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON BANTUL',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KAPANEWON GODEAN',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON BANTUL',
#   'KAPANEWON BANGUNTAPAN',
#   'KAPANEWON PLERET',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON BANGUNTAPAN',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KAPANEWON DEPOK',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON BANGUNTAPAN',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KAPANEWON DEPOK',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON BANGUNTAPAN',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KAPANEWON DEPOK',
#   'KAPANEWON BERBAH',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON JETIS',
#   'KAPANEWON BANGUNTAPAN',
#   'KAPANEWON PLERET',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KAPANEWON DEPOK',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON BANGUNTAPAN',
#   'KAPANEWON PLERET',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KAPANEWON DEPOK',
#   'KAPANEWON BERBAH',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['KAPANEWON BANGUNTAPAN',
#   'KAPANEWON PLERET',
#   'KAPANEWON SEWON',
#   'KAPANEWON KASIHAN',
#   'KAPANEWON GAMPING',
#   'KAPANEWON DEPOK',
#   'KAPANEWON BERBAH',
#   'KEMANTREN TEGALREJO',
#   'KEMANTREN JETIS',
#   'KEMANTREN GONDOKUSUMAN',
#   'KEMANTREN DANUREJAN',
#   'KEMANTREN GEDONGTENGEN',
#   'KEMANTREN NGAMPILAN',
#   'KEMANTREN WIROBRAJAN',
#   'KEMANTREN MANTRIJERON',
#   'KEMANTREN KRATON',
#   'KEMANTREN GONDOMANAN',
#   'KEMANTREN PAKUALAMAN',
#   'KEMANTREN MERGANGSAN',
#   'KEMANTREN UMBULHARJO',
#   'KEMANTREN KOTAGEDE'],
#  ['Bandongan', 'Magelang Tengah', 'Magelang Utara'],
#  ['Borobudur'],
#  ['Candimulyo', 'Sawangan', 'Tegalrejo'],
#  ['Dukun', 'Srumbung'],
#  ['Grabag', 'Ngablak'],
#  ['Kajoran', 'Kaliangkrik'],
#  ['Kajoran', 'Kaliangkrik'],
#  ['Mertoyudan', 'Magelang Selatan'],
#  ['Mungkid', 'Muntilan', 'Salam'],
#  ['Mungkid', 'Muntilan', 'Salam'],
#  ['Grabag', 'Ngablak'],
#  ['KAPANEWON KALIBAWANG', 'Ngluwar', 'Salam'],
#  ['Pakis'],
#  ['KAPANEWON KALIBAWANG', 'Mungkid', 'Muntilan', 'Ngluwar', 'Salam'],
#  ['Salaman'],
#  ['Candimulyo', 'Sawangan'],
#  ['Secang'],
#  ['Dukun', 'Srumbung'],
#  ['Candimulyo',
#   'Tegalrejo',
#   'Magelang Selatan',
#   'Magelang Tengah',
#   'Magelang Utara'],
#  ['Tempuran'],
#  ['Windusari'],
#  ['Candimulyo',
#   'Mertoyudan',
#   'Tegalrejo',
#   'Magelang Selatan',
#   'Magelang Tengah',
#   'Magelang Utara'],
#  ['Bandongan',
#   'Tegalrejo',
#   'Magelang Selatan',
#   'Magelang Tengah',
#   'Magelang Utara'],
#  ['Bandongan',
#   'Tegalrejo',
#   'Magelang Selatan',
#   'Magelang Tengah',
#   'Magelang Utara'],
#  ['Bayat', 'Cawas', 'Kalikotes', 'Klaten Tengah', 'Trucuk', 'Wedi'],
#  ['Bayat', 'Cawas', 'Karangdowo', 'Trucuk'],
#  ['Ceper',
#   'Delanggu',
#   'Juwiring',
#   'Karanganom',
#   'Klaten Tengah',
#   'Klaten Utara',
#   'Ngawen',
#   'Pedan',
#   'Polanharjo',
#   'Trucuk'],
#  ['Ceper', 'Delanggu', 'Juwiring', 'Polanharjo'],
#  ['KAPANEWON PRAMBANAN',
#   'KAPANEWON KALASAN',
#   'Gantiwarno',
#   'Klaten Selatan',
#   'Prambanan',
#   'Wedi'],
#  ['Jatinom', 'Karanganom', 'Karangnongko', 'Tulung'],
#  ['KAPANEWON PRAMBANAN',
#   'KAPANEWON KALASAN',
#   'Jogonalan',
#   'Karangnongko',
#   'Kebonarum',
#   'Klaten Selatan',
#   'Manisrenggo',
#   'Prambanan',
#   'Wedi'],
#  ['Delanggu', 'Juwiring', 'Karangdowo', 'Pedan', 'Wonosari'],
#  ['Bayat',
#   'Ceper',
#   'Kalikotes',
#   'Kebonarum',
#   'Klaten Selatan',
#   'Klaten Tengah',
#   'Klaten Utara',
#   'Ngawen',
#   'Trucuk',
#   'Wedi'],
#  ['Ceper',
#   'Jatinom',
#   'Karanganom',
#   'Klaten Utara',
#   'Ngawen',
#   'Polanharjo',
#   'Tulung'],
#  ['Cawas', 'Juwiring', 'Karangdowo', 'Pedan'],
#  ['KAPANEWON CANGKRINGAN',
#   'Jatinom',
#   'Jogonalan',
#   'Karangnongko',
#   'Kebonarum',
#   'Manisrenggo'],
#  ['Jogonalan',
#   'Kalikotes',
#   'Karangnongko',
#   'Kebonarum',
#   'Klaten Selatan',
#   'Klaten Tengah',
#   'Klaten Utara',
#   'Ngawen',
#   'Wedi'],
#  ['KAPANEWON TURI', 'KAPANEWON PAKEM', 'Kemalang'],
#  ['KAPANEWON PRAMBANAN',
#   'Jogonalan',
#   'Kalikotes',
#   'Kebonarum',
#   'Klaten Selatan',
#   'Klaten Tengah',
#   'Klaten Utara',
#   'Wedi'],
#  ['Bayat',
#   'Ceper',
#   'Kalikotes',
#   'Kebonarum',
#   'Klaten Selatan',
#   'Klaten Tengah',
#   'Klaten Utara',
#   'Ngawen',
#   'Trucuk',
#   'Wedi'],
#  ['Ceper',
#   'Kalikotes',
#   'Karanganom',
#   'Klaten Selatan',
#   'Klaten Tengah',
#   'Klaten Utara',
#   'Ngawen',
#   'Trucuk'],
#  ['KAPANEWON NGEMPLAK',
#   'KAPANEWON NGAGLIK',
#   'KAPANEWON PAKEM',
#   'KAPANEWON CANGKRINGAN',
#   'Karangnongko',
#   'Manisrenggo',
#   'Prambanan'],
#  ['Ceper',
#   'Kalikotes',
#   'Karanganom',
#   'Klaten Tengah',
#   'Klaten Utara',
#   'Ngawen'],
#  ['Ceper', 'Juwiring', 'Karangdowo', 'Pedan', 'Trucuk'],
#  ['Ceper', 'Delanggu', 'Karanganom', 'Polanharjo'],
#  ['KAPANEWON BERBAH',
#   'KAPANEWON PRAMBANAN',
#   'KAPANEWON KALASAN',
#   'KAPANEWON NGEMPLAK',
#   'Gantiwarno',
#   'Jogonalan',
#   'Manisrenggo',
#   'Prambanan'],
#  ['Bayat',
#   'Cawas',
#   'Ceper',
#   'Kalikotes',
#   'Klaten Tengah',
#   'Klaten Utara',
#   'Pedan',
#   'Trucuk'],
#  ['Jatinom', 'Karanganom', 'Tulung'],
#  ['Bayat',
#   'Gantiwarno',
#   'Kalikotes',
#   'Kebonarum',
#   'Klaten Selatan',
#   'Klaten Tengah',
#   'Wedi'],
#  ['Juwiring', 'Wonosari']]

# %%
# Constraints for apalah 9tu 
for i in demand_points:
    problem += pulp.lpSum([facility_open[j] for j in N[i]]) >= demand_point[i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Constraints for apalah 9tu
#       2 for i in demand_points:
# ----> 3     problem += pulp.lpSum([facility_open[j] for j in N[i]]) >= demand_point[i]
#
# TypeError: list indices must be integers or slices, not str

# %%
for i in demand_points: 
    [facility_open[j] for j in N[i]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 for i in demand_points:
# ----> 2     [facility_open[j] for j in N[i]]
#
# TypeError: list indices must be integers or slices, not str

# %%
problem
# Out:
# MCLP:
# MAXIMIZE
# 995.6688970287411*y_KAPANEWON_GALUR + 264.99838942034404*y_KAPANEWON_LENDAH + 399.19977941125984*y_KAPANEWON_PANJATAN + 701.8332726696367*y_KAPANEWON_TEMON + 381.9918375968616*y_KAPANEWON_WATES + 0.0
# SUBJECT TO
# _C1: x_KAPANEWON_GALUR + x_KAPANEWON_LENDAH + x_KAPANEWON_PANJATAN
#  + x_KAPANEWON_TEMON + x_KAPANEWON_WATES = 3
#
# _C2: x_KAPANEWON_TEMON + x_KAPANEWON_WATES - y_KAPANEWON_TEMON >= 0
#
# _C3: x_KAPANEWON_PANJATAN + x_KAPANEWON_TEMON + x_KAPANEWON_WATES
#  - y_KAPANEWON_WATES >= 0
#
# _C4: x_KAPANEWON_GALUR + x_KAPANEWON_LENDAH + x_KAPANEWON_PANJATAN
#  + x_KAPANEWON_WATES - y_KAPANEWON_PANJATAN >= 0
#
# _C5: x_KAPANEWON_GALUR + x_KAPANEWON_LENDAH + x_KAPANEWON_PANJATAN
#  - y_KAPANEWON_GALUR >= 0
#
# _C6: x_KAPANEWON_GALUR + x_KAPANEWON_LENDAH + x_KAPANEWON_PANJATAN
#  - y_KAPANEWON_LENDAH >= 0
#
# VARIABLES
# 0 <= x_KAPANEWON_GALUR <= 1 Integer
# 0 <= x_KAPANEWON_LENDAH <= 1 Integer
# 0 <= x_KAPANEWON_PANJATAN <= 1 Integer
# 0 <= x_KAPANEWON_TEMON <= 1 Integer
# 0 <= x_KAPANEWON_WATES <= 1 Integer
# 0 <= y_KAPANEWON_GALUR <= 1 Integer
# 0 <= y_KAPANEWON_LENDAH <= 1 Integer
# 0 <= y_KAPANEWON_PANJATAN <= 1 Integer
# 0 <= y_KAPANEWON_TEMON <= 1 Integer
# 0 <= y_KAPANEWON_WATES <= 1 Integer

# %%
problem.solve()
# Out:
# 1

# %%
facility_open
# Out:
# {'KAPANEWON TEMON': x_KAPANEWON_TEMON,
#  'KAPANEWON WATES': x_KAPANEWON_WATES,
#  'KAPANEWON PANJATAN': x_KAPANEWON_PANJATAN,
#  'KAPANEWON GALUR': x_KAPANEWON_GALUR,
#  'KAPANEWON LENDAH': x_KAPANEWON_LENDAH}

# %%
x_soln = np.array([facility_open[j].varValue for j in facilities])
x_soln

y_soln = np.array([demand_point[j].varValue for j in demand_points])
# And print some output
print (("Status:"), pulp.LpStatus[problem.status])
print ("Population Served is = ", pulp.value(problem.objective))
print("total demand : ", sum(list(demands.values())))
print ("x = ", x_soln)
print("y = ", y_soln)
# Out:
# Status: Optimal
# Population Served is =  2743.6921761268436
# total demand :  2743.6921761268436
# x =  [1. 0. 0. 1. 1.]
# y =  [1. 1. 1. 1. 1.]

# %%
# Out:
# 2743.6921761268436
